# %%
pip install pygame
# Out:
# Requirement already satisfied: pygame in /usr/local/lib/python3.12/dist-packages (2.6.1)

# %%
import pygame
import math

pygame.init()

linear_speed = 0
angular_speed = 0

#linear_speed = 50
#angular_speed = 50

# TODO: Создайте окно 800x600
WIDTH = 800
HEIGHT = 600
screen = pygame.display.set_mode(size=(WIDTH, HEIGHT))

# TODO: Создайте часы для контроля FPS
clock = pygame.time.Clock()

# TODO: Определите цвета (WHITE, BLACK, BLUE)
WHITE = (255, 255, 255)
BLACK = (0, 0, 0)
BLUE = (0, 0, 255)

# TODO: Создайте шрифт размером 24
font = pygame.font.Font(None, 24)

dt = clock.tick(60) / 1000.0

# TODO: Переменные робота (математические координаты)
robot_x = 0  # начальная позиция в математических координатах
robot_y = 0  # начальная позиция в математических координатах
robot_direction = 0  # градусы, 0 = вправо

def draw_robot(screen, x, y, direction, radius):
    """Рисует робота с направлением"""
    # TODO: Преобразуйте математические координаты в экранные

    screen_x = x + WIDTH // 2
    screen_y = HEIGHT // 2 - y
    draw_info(screen, x, y, direction, linear_speed, angular_speed)
    # TODO: Нарисуйте круг (тело робота)
    pygame.draw.circle(screen, color=BLUE, center=(screen_x, screen_y), radius=radius)

    # TODO: Вычислите координаты треугольника для направления
    angle_rad = math.radians(direction)

    # Вершина треугольника (впереди)
    tip_x = screen_x + radius * math.cos(angle_rad)  # используйте screen_x, radius, cos(angle_rad)
    tip_y = screen_y - radius * math.sin(angle_rad)  # используйте screen_y, radius, sin(angle_rad)

    # Задние углы треугольника (левый и правый)
    # Подсказка: используйте углы (angle_rad + 2.5) и (angle_rad - 2.5)
    left_x = screen_x + radius * math.cos(angle_rad + 2.5) * 0.5
    left_y = screen_y - radius * math.sin(angle_rad + 2.5) * 0.5

    right_x = screen_x + radius * math.cos(angle_rad - 2.5) * 0.5
    right_y = screen_y - radius * math.sin(angle_rad - 2.5) * 0.5

    # TODO: Нарисуйте треугольник
    pygame.draw.polygon(surface=screen, color=WHITE, points=[(tip_x, tip_y), (left_x, left_y), (right_x, right_y)])

    # TODO: Нарисуйте контур круга (толщина 2)
    pygame.draw.circle(surface=screen, color=BLACK, center=(screen_x, screen_y), radius=radius, width=2)

def draw_info(screen, x, y, direction, linear_speed, angular_speed):
    """Отображает информацию о роботе на экране"""
    # TODO: Создайте список строк с информацией
    lines = [
        f"Позиция: ({int(x)}, {int(y)})",
        f"Угол: {int(direction % 360)}°",
        f"Скорость: {int(linear_speed)} пикс/с"
    ]

    # TODO: Отрисуйте каждую строку
    y_offset = 10
    for line in lines:
        text_surface = font.render(line, True, BLACK)
        screen.blit(source=text_surface, dest=(10, y_offset))
        y_offset += 25
        pass

# Игровой цикл
running = True
while running:
    # TODO: Обработка событий
    for event in pygame.event.get():
        if event.type == pygame.QUIT:
            running = False

        # Телепортация по клику мыши
        if event.type == pygame.MOUSEBUTTONDOWN:
            if event.button == 1:
                mouse_screen_x, mouse_screen_y = event.pos
                robot_x = mouse_screen_x - WIDTH // 2
                robot_y = HEIGHT // 2 - mouse_screen_y
                print(f"Телепортация в ({int(robot_x)}, {int(robot_y)})")
            # Средняя кнопка — возврат в центр
            if event.button == 2:
                robot_x = 0
                robot_y = 0
                print("Возврат в центр")

    # TODO: Вычисляйте delta time
    dt = clock.tick(60) / 1000.0

    # TODO: Обнуляем скорости (если клавиши не нажаты, робот стоит)
    linear_speed = 0
    angular_speed = 0

    # TODO: Получаем состояние всех клавиш
    keys = pygame.key.get_pressed()

    # TODO: Управление линейной скоростью
    # Сначала проверьте конфликт: если W и S нажаты одновременно
    if keys[pygame.K_w] and keys[pygame.K_s]:
        linear_speed = 0
    # Затем проверьте W отдельно (используйте elif!)
    elif keys[pygame.K_w]:
        linear_speed = 150
    # Затем проверьте S отдельно (используйте elif!)
    elif keys[pygame.K_s]:
        linear_speed = -100
    # TODO: Управление угловой скоростью
    # Можете сделать проверку A+D для полноты, или просто две отдельные проверки
    if keys[pygame.K_a]:
        angular_speed = 120  # Влево (против часовой)
    if keys[pygame.K_d]:
        angular_speed = -120  # Вправо (по часовой)

    # TODO: Обновите направление робота
    robot_direction += angular_speed * dt

    # TODO: Обновите позицию робота
    # Сначала вычислите угол в радианах
    angle_rad = math.radians(robot_direction)

    # Затем вычислите изменение координат и обновите позицию
    robot_x += linear_speed * math.cos(angle_rad) * dt
    robot_y += linear_speed * math.sin(angle_rad) * dt

    # TODO: Залить экран белым
    screen.fill(WHITE)

    # TODO: Нарисовать робота
    draw_robot(screen=screen, x=robot_x, y=robot_y, direction=robot_direction, radius=20)

    # Обновление экрана
    pygame.display.flip()

pygame.quit()
# Out:
# pygame 2.6.1 (SDL 2.28.4, Python 3.12.12)
# Hello from the pygame community. https://www.pygame.org/contribute.html
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipython-input-2346160903.py in <cell line: 0>()
#     145
#     146     # TODO: Нарисовать робота
# --> 147     draw_robot(screen=screen, x=robot_x, y=robot_y, direction=robot_direction, radius=20)
#     148
#     149     # Обновление экрана
#
# /tmp/ipython-input-2346160903.py in draw_robot(screen, x, y, direction, radius)
#      39     screen_x = x + WIDTH // 2
#      40     screen_y = HEIGHT // 2 - y
# ---> 41     draw_info(screen, x, y, direction, linear_speed, angular_speed)
#      42     # TODO: Нарисуйте круг (тело робота)
#      43     pygame.draw.circle(screen, color=BLUE, center=(screen_x, screen_y), radius=radius)
#
# /tmp/ipython-input-2346160903.py in draw_info(screen, x, y, direction, linear_speed, angular_speed)
#      76     y_offset = 10
#      77     for line in lines:
# ---> 78         text_surface = font.render(line, True, BLACK)
#      79         screen.blit(source=text_surface, dest=(10, y_offset))
#      80         y_offset += 25
#
# KeyboardInterrupt:

# %%
import pygame
import math

pygame.init()

linear_speed = 0
angular_speed = 0

#linear_speed = 50
#angular_speed = 50

# TODO: Создайте окно 800x600
WIDTH = 800
HEIGHT = 600
screen = pygame.display.set_mode(size=(WIDTH, HEIGHT))

# TODO: Создайте часы для контроля FPS
clock = pygame.time.Clock()

# TODO: Определите цвета (WHITE, BLACK, BLUE)
WHITE = (255, 255, 255)
BLACK = (0, 0, 0)
BLUE = (0, 0, 255)

# TODO: Создайте шрифт размером 24
font = pygame.font.Font(None, 24)

dt = clock.tick(60) / 1000.0

# TODO: Переменные робота (математические координаты)
robot_x = 0  # начальная позиция в математических координатах
robot_y = 0  # начальная позиция в математических координатах
robot_direction = 0  # градусы, 0 = вправо

def draw_robot(screen, x, y, direction, radius):
	"""Рисует робота с направлением"""
	# TODO: Преобразуйте математические координаты в экранные

	screen_x = x + WIDTH // 2
	screen_y = HEIGHT // 2 - y
	draw_info(screen, x, y, direction, linear_speed, angular_speed)
	# TODO: Нарисуйте круг (тело робота)
	pygame.draw.circle(screen, color=BLUE, center=(screen_x, screen_y), radius=radius)

	# TODO: Вычислите координаты треугольника для направления
	angle_rad = math.radians(direction)

	# Вершина треугольника (впереди)
	tip_x = screen_x + radius * math.cos(angle_rad)  # используйте screen_x, radius, cos(angle_rad)
	tip_y = screen_y - radius * math.sin(angle_rad)  # используйте screen_y, radius, sin(angle_rad)

	# Задние углы треугольника (левый и правый)
	# Подсказка: используйте углы (angle_rad + 2.5) и (angle_rad - 2.5)
	left_x = screen_x + radius * math.cos(angle_rad + 2.5) * 0.5
	left_y = screen_y - radius * math.sin(angle_rad + 2.5) * 0.5

	right_x = screen_x + radius * math.cos(angle_rad - 2.5) * 0.5
	right_y = screen_y - radius * math.sin(angle_rad - 2.5) * 0.5

	# TODO: Нарисуйте треугольник
	pygame.draw.polygon(surface=screen, color=WHITE, points=[(tip_x, tip_y), (left_x, left_y), (right_x, right_y)])

	# TODO: Нарисуйте контур круга (толщина 2)
	pygame.draw.circle(surface=screen, color=BLACK, center=(screen_x, screen_y), radius=radius, width=2)

def draw_info(screen, x, y, direction, linear_speed, angular_speed):
	"""Отображает информацию о роботе на экране"""
	# TODO: Создайте список строк с информацией
	lines = [
		f"Позиция: ({int(x)}, {int(y)})",
		f"Угол: {int(direction % 360)}°",
		f"Скорость: {int(linear_speed)} пикс/с"
	]

	# TODO: Отрисуйте каждую строку
	y_offset = 10
	for line in lines:
		text_surface = font.render(line, True, BLACK)
		screen.blit(source=text_surface, dest=(10, y_offset))
		y_offset += 25
		pass

# Игровой цикл
running = True
while running:
	# TODO: Обработка событий
	for event in pygame.event.get():
		if event.type == pygame.QUIT:
			running = False

		if event.type == pygame.MOUSEBUTTONDOWN:
			if event.button == 1:
				mouse_screen_x, mouse_screen_y = event.pos
				robot_x = mouse_screen_x - WIDTH // 2
				robot_y = HEIGHT // 2 - mouse_screen_y
				print(f"Телепортация в ({int(robot_x)}, {int(robot_y)})")
			if event.button == 2:
				robot_x = 0
				robot_y = 0
				print("Возврат в центр")

	# TODO: Вычисляйте delta time
	dt = clock.tick(60) / 1000.0

	# TODO: Обнуляем скорости (если клавиши не нажаты, робот стоит)
	linear_speed = 0
	angular_speed = 0

	# TODO: Получаем состояние всех клавиш
	keys = pygame.key.get_pressed()

	# TODO: Управление линейной скоростью
	# Сначала проверьте конфликт: если W и S нажаты одновременно
	if keys[pygame.K_w] and keys[pygame.K_s]:
		linear_speed = 0
	# Затем проверьте W отдельно (используйте elif!)
	elif keys[pygame.K_w]:
		linear_speed = 150
	# Затем проверьте S отдельно (используйте elif!)
	elif keys[pygame.K_s]:
		linear_speed = -100
	# TODO: Управление угловой скоростью
	# Можете сделать проверку A+D для полноты, или просто две отдельные проверки
	if keys[pygame.K_a]:
		angular_speed = 120  # Влево (против часовой)
	if keys[pygame.K_d]:
		angular_speed = -120  # Вправо (по часовой)

	# TODO: Обновите направление робота
	robot_direction += angular_speed * dt

	# TODO: Обновите позицию робота
	# Сначала вычислите угол в радианах
	angle_rad = math.radians(robot_direction)

	# Затем вычислите изменение координат и обновите позицию
	robot_x += linear_speed * math.cos(angle_rad) * dt
	robot_y += linear_speed * math.sin(angle_rad) * dt

	# TODO: Залить экран белым
	screen.fill(WHITE)

	# TODO: Нарисовать робота
	draw_robot(screen=screen, x=robot_x, y=robot_y, direction=robot_direction, radius=20)

	# Обновление экрана
	pygame.display.flip()

pygame.quit()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipython-input-1960983699.py in <cell line: 0>()
#     104
#     105         # TODO: Вычисляйте delta time
# --> 106         dt = clock.tick(60) / 1000.0
#     107
#     108         # TODO: Обнуляем скорости (если клавиши не нажаты, робот стоит)
#
# KeyboardInterrupt:

# %%
import pygame
import math

pygame.init()

linear_speed = 0
angular_speed = 0

#linear_speed = 50
#angular_speed = 50

# TODO: Создайте окно 800x600
WIDTH = 800
HEIGHT = 600
screen = pygame.display.set_mode(size=(WIDTH, HEIGHT))

# TODO: Создайте часы для контроля FPS
clock = pygame.time.Clock()

# TODO: Определите цвета (WHITE, BLACK, BLUE)
WHITE = (255, 255, 255)
BLACK = (0, 0, 0)
BLUE = (0, 0, 255)

# TODO: Создайте шрифт размером 24
font = pygame.font.Font(None, 24)

dt = clock.tick(60) / 1000.0

# TODO: Переменные робота (математические координаты)
robot_x = 0  # начальная позиция в математических координатах
robot_y = 0  # начальная позиция в математических координатах
robot_direction = 0  # градусы, 0 = вправо

def draw_robot(screen, x, y, direction, radius):
    """Рисует робота с направлением"""
    # TODO: Преобразуйте математические координаты в экранные

    screen_x = x + WIDTH // 2
    screen_y = HEIGHT // 2 - y
    draw_info(screen, x, y, direction, linear_speed, angular_speed)
    # TODO: Нарисуйте круг (тело робота)
    pygame.draw.circle(screen, color=BLUE, center=(screen_x, screen_y), radius=radius)

    # TODO: Вычислите координаты треугольника для направления
    angle_rad = math.radians(direction)

    # Вершина треугольника (впереди)
    tip_x = screen_x + radius * math.cos(angle_rad)  # используйте screen_x, radius, cos(angle_rad)
    tip_y = screen_y - radius * math.sin(angle_rad)  # используйте screen_y, radius, sin(angle_rad)

    # Задние углы треугольника (левый и правый)
    # Подсказка: используйте углы (angle_rad + 2.5) и (angle_rad - 2.5)
    left_x = screen_x + radius * math.cos(angle_rad + 2.5) * 0.5
    left_y = screen_y - radius * math.sin(angle_rad + 2.5) * 0.5

    right_x = screen_x + radius * math.cos(angle_rad - 2.5) * 0.5
    right_y = screen_y - radius * math.sin(angle_rad - 2.5) * 0.5

    # TODO: Нарисуйте треугольник
    pygame.draw.polygon(surface=screen, color=WHITE, points=[(tip_x, tip_y), (left_x, left_y), (right_x, right_y)])

    # TODO: Нарисуйте контур круга (толщина 2)
    pygame.draw.circle(surface=screen, color=BLACK, center=(screen_x, screen_y), radius=radius, width=2)

def draw_info(screen, x, y, direction, linear_speed, angular_speed):
    """Отображает информацию о роботе на экране"""
    # TODO: Создайте список строк с информацией
    lines = [
        f"Позиция: ({int(x)}, {int(y)})",
        f"Угол: {int(direction % 360)}°",
        f"Скорость: {int(linear_speed)} пикс/с",
        f"Угл. скорость: {int(angular_speed)} °/с"  # [AI] Добавлен вывод угловой скорости
    ]

    # TODO: Отрисуйте каждую строку
    y_offset = 10
    for line in lines:
        text_surface = font.render(line, True, BLACK)
        screen.blit(source=text_surface, dest=(10, y_offset))
        y_offset += 25
        pass

# Игровой цикл
running = True
while running:
    # TODO: Обработка событий
    for event in pygame.event.get():
        if event.type == pygame.QUIT:
            running = False


        if event.type == pygame.MOUSEBUTTONDOWN:

            if event.button == 1:
                mouse_screen_x, mouse_screen_y = event.pos
                robot_x = mouse_screen_x - WIDTH // 2
                robot_y = HEIGHT // 2 - mouse_screen_y
                print(f"Телепортация в ({int(robot_x)}, {int(robot_y)})")

            if event.button == 2:
                robot_x = 0
                robot_y = 0
                print("Возврат в центр")

    # TODO: Вычисляйте delta time
    dt = clock.tick(60) / 1000.0

    # TODO: Обнуляем скорости (если клавиши не нажаты, робот стоит)
    linear_speed = 0
    angular_speed = 0


    mouse_screen_x, mouse_screen_y = pygame.mouse.get_pos()

    target_x = mouse_screen_x - WIDTH // 2
    target_y = HEIGHT // 2 - mouse_screen_y

    dx = target_x - robot_x
    dy = target_y - robot_y
    distance = math.hypot(dx, dy)

    angle_to_target_rad = math.atan2(dy, dx)
    angle_to_target_deg = math.degrees(angle_to_target_rad)

    angle_difference = angle_to_target_deg - robot_direction
    if angle_difference > 180:
        angle_difference -= 360
    elif angle_difference < -180:
        angle_difference += 360

    angular_speed = max(-180, min(180, angle_difference * 5))

    if distance > 5 and abs(angle_difference) < 30:
        linear_speed = 150
    else:
        linear_speed = 0

    # keys = pygame.key.get_pressed()
    # if keys[pygame.K_w] and keys[pygame.K_s]:
    #     linear_speed = 0
    # elif keys[pygame.K_w]:
    #     linear_speed = 150
    # elif keys[pygame.K_s]:
    #     linear_speed = -100
    # if keys[pygame.K_a]:
    #     angular_speed = 120
    # if keys[pygame.K_d]:
    #     angular_speed = -120

    # TODO: Обновите направление робота
    robot_direction += angular_speed * dt

    # TODO: Обновите позицию робота
    # Сначала вычислите угол в радианах
    angle_rad = math.radians(robot_direction)

    # Затем вычислите изменение координат и обновите позицию
    robot_x += linear_speed * math.cos(angle_rad) * dt
    robot_y += linear_speed * math.sin(angle_rad) * dt

    # TODO: Залить экран белым
    screen.fill(WHITE)

    # TODO: Нарисовать робота
    draw_robot(screen=screen, x=robot_x, y=robot_y, direction=robot_direction, radius=20)

    # Обновление экрана
    pygame.display.flip()

pygame.quit()

# %%
import pygame
import math

pygame.init()

linear_speed = 0
angular_speed = 0

#linear_speed = 50
#angular_speed = 50

# TODO: Создайте окно 800x600
WIDTH = 800
HEIGHT = 600
screen = pygame.display.set_mode(size=(WIDTH, HEIGHT))

# TODO: Создайте часы для контроля FPS
clock = pygame.time.Clock()

# TODO: Определите цвета (WHITE, BLACK, BLUE)
WHITE = (255, 255, 255)
BLACK = (0, 0, 0)
BLUE = (0, 0, 255)

# TODO: Создайте шрифт размером 24
font = pygame.font.Font(None, 24)

dt = clock.tick(60) / 1000.0

# TODO: Переменные робота (математические координаты)
robot_x = 0  # начальная позиция в математических координатах
robot_y = 0  # начальная позиция в математических координатах
robot_direction = 0  # градусы, 0 = вправо

control_mode = "keyboard"

def draw_robot(screen, x, y, direction, radius):
    """Рисует робота с направлением"""
    # TODO: Преобразуйте математические координаты в экранные

    screen_x = x + WIDTH // 2
    screen_y = HEIGHT // 2 - y
    draw_info(screen, x, y, direction, linear_speed, angular_speed, control_mode)  # [AI] Передаём текущий режим
    # TODO: Нарисуйте круг (тело робота)
    pygame.draw.circle(screen, color=BLUE, center=(screen_x, screen_y), radius=radius)

    # TODO: Вычислите координаты треугольника для направления
    angle_rad = math.radians(direction)

    # Вершина треугольника (впереди)
    tip_x = screen_x + radius * math.cos(angle_rad)  # используйте screen_x, radius, cos(angle_rad)
    tip_y = screen_y - radius * math.sin(angle_rad)  # используйте screen_y, radius, sin(angle_rad)

    # Задние углы треугольника (левый и правый)
    # Подсказка: используйте углы (angle_rad + 2.5) и (angle_rad - 2.5)
    left_x = screen_x + radius * math.cos(angle_rad + 2.5) * 0.5
    left_y = screen_y - radius * math.sin(angle_rad + 2.5) * 0.5

    right_x = screen_x + radius * math.cos(angle_rad - 2.5) * 0.5
    right_y = screen_y - radius * math.sin(angle_rad - 2.5) * 0.5

    # TODO: Нарисуйте треугольник
    pygame.draw.polygon(surface=screen, color=WHITE, points=[(tip_x, tip_y), (left_x, left_y), (right_x, right_y)])

    # TODO: Нарисуйте контур круга (толщина 2)
    pygame.draw.circle(surface=screen, color=BLACK, center=(screen_x, screen_y), radius=radius, width=2)

def draw_info(screen, x, y, direction, linear_speed, angular_speed, mode):
    """Отображает информацию о роботе на экране"""
    # TODO: Создайте список строк с информацией
    lines = [
        f"Позиция: ({int(x)}, {int(y)})",
        f"Направление: {int(direction % 360)}°",
        f"Линейная скорость: {int(linear_speed)} пикс/с",
        f"Угловая скорость: {int(angular_speed)} град/с",
        f"Режим: {mode}",  # [AI] Показ текущего режима
        "Tab - переключить режим, R - сброс"
    ]

    # TODO: Отрисуйте каждую строку
    y_offset = 10
    for line in lines:
        text_surface = font.render(line, True, BLACK)
        screen.blit(source=text_surface, dest=(10, y_offset))
        y_offset += 25
        pass

# Игровой цикл
running = True
while running:
    # TODO: Обработка событий
    for event in pygame.event.get():
        if event.type == pygame.QUIT:
            running = False


        if event.type == pygame.MOUSEBUTTONDOWN:
            if event.button == 1:
                mouse_screen_x, mouse_screen_y = event.pos
                robot_x = mouse_screen_x - WIDTH // 2
                robot_y = HEIGHT // 2 - mouse_screen_y
                print(f"Телепортация в ({int(robot_x)}, {int(robot_y)})")
            if event.button == 2:
                robot_x = 0
                robot_y = 0
                robot_direction = 0
                print("Возврат в центр")

        #Переключение режимов и сброс по клавиатуре
        if event.type == pygame.KEYDOWN:
            if event.key == pygame.K_TAB:
                if control_mode == "keyboard":
                    control_mode = "mouse"
                    print("Режим: следование за мышью")
                else:
                    control_mode = "keyboard"
                    print("Режим: управление клавиатурой")
            if event.key == pygame.K_r:
                robot_x = 0
                robot_y = 0
                robot_direction = 0
                print("Позиция сброшена")

    # TODO: Вычисляйте delta time
    dt = clock.tick(60) / 1000.0

    # TODO: Обнуляем скорости (если клавиши не нажаты, робот стоит)
    linear_speed = 0
    angular_speed = 0

    if control_mode == "keyboard":
        # TODO: Код управления клавиатурой (WASD)
        keys = pygame.key.get_pressed()

        # Управление линейной скоростью
        if keys[pygame.K_w] and keys[pygame.K_s]:
            linear_speed = 0
        elif keys[pygame.K_w]:
            linear_speed = 150
        elif keys[pygame.K_s]:
            linear_speed = -100

        # Управление угловой скоростью
        if keys[pygame.K_a]:
            angular_speed = 120
        if keys[pygame.K_d]:
            angular_speed = -120

    elif control_mode == "mouse":
        # TODO: Код следования за мышью
        mouse_screen_x, mouse_screen_y = pygame.mouse.get_pos()
        target_x = mouse_screen_x - WIDTH // 2
        target_y = HEIGHT // 2 - mouse_screen_y

        dx = target_x - robot_x
        dy = target_y - robot_y
        distance = math.hypot(dx, dy)

        angle_to_target_rad = math.atan2(dy, dx)
        angle_to_target_deg = math.degrees(angle_to_target_rad)

        angle_difference = angle_to_target_deg - robot_direction
        if angle_difference > 180:
            angle_difference -= 360
        elif angle_difference < -180:
            angle_difference += 360

        if abs(angle_difference) > 5:
            angular_speed = max(-180, min(180, angle_difference * 5))
        else:
            angular_speed = 0

        if distance > 5 and abs(angle_difference) < 30:
            linear_speed = 150
        else:
            linear_speed = 0

    # TODO: Обновите направление робота
    robot_direction += angular_speed * dt

    # TODO: Обновите позицию робота
    # Сначала вычислите угол в радианах
    angle_rad = math.radians(robot_direction)

    # Затем вычислите изменение координат и обновите позицию
    robot_x += linear_speed * math.cos(angle_rad) * dt
    robot_y += linear_speed * math.sin(angle_rad) * dt

    # TODO: Залить экран белым
    screen.fill(WHITE)

    # TODO: Нарисовать робота
    draw_robot(screen=screen, x=robot_x, y=robot_y, direction=robot_direction, radius=20)

    # Обновление экрана
    pygame.display.flip()

pygame.quit()

# %%
import pygame
import math

pygame.init()

linear_speed = 0
angular_speed = 0

#linear_speed = 50
#angular_speed = 50

# TODO: Создайте окно 800x600
WIDTH = 800
HEIGHT = 600
screen = pygame.display.set_mode(size=(WIDTH, HEIGHT))

# TODO: Создайте часы для контроля FPS
clock = pygame.time.Clock()

# TODO: Определите цвета (WHITE, BLACK, BLUE)
WHITE = (255, 255, 255)
BLACK = (0, 0, 0)
BLUE = (0, 0, 255)

# TODO: Создайте шрифт размером 24
font = pygame.font.Font(None, 24)

dt = clock.tick(60) / 1000.0

# TODO: Переменные робота (математические координаты)
robot_x = 0  # начальная позиция в математических координатах
robot_y = 0  # начальная позиция в математических координатах
robot_direction = 0  # градусы, 0 = вправо

# Режим управления
control_mode = "keyboard"

# TODO: Создайте переменную для множителя скорости
speed_multiplier = 1.0  # Начальное значение 1.0

# TODO: Определите границы (математические координаты)
MAX_X = WIDTH // 2 - 20
MAX_Y = HEIGHT // 2 - 20

def draw_robot(screen, x, y, direction, radius):
    """Рисует робота с направлением"""
    # TODO: Преобразуйте математические координаты в экранные

    screen_x = x + WIDTH // 2
    screen_y = HEIGHT // 2 - y
    draw_info(screen, x, y, direction, linear_speed, angular_speed, control_mode, speed_multiplier)
    # TODO: Нарисуйте круг (тело робота)
    pygame.draw.circle(screen, color=BLUE, center=(screen_x, screen_y), radius=radius)

    # TODO: Вычислите координаты треугольника для направления
    angle_rad = math.radians(direction)

    # Вершина треугольника (впереди)
    tip_x = screen_x + radius * math.cos(angle_rad)
    tip_y = screen_y - radius * math.sin(angle_rad)

    # Задние углы треугольника (левый и правый)
    left_x = screen_x + radius * math.cos(angle_rad + 2.5) * 0.5
    left_y = screen_y - radius * math.sin(angle_rad + 2.5) * 0.5

    right_x = screen_x + radius * math.cos(angle_rad - 2.5) * 0.5
    right_y = screen_y - radius * math.sin(angle_rad - 2.5) * 0.5

    # TODO: Нарисуйте треугольник
    pygame.draw.polygon(surface=screen, color=WHITE, points=[(tip_x, tip_y), (left_x, left_y), (right_x, right_y)])

    # TODO: Нарисуйте контур круга (толщина 2)
    pygame.draw.circle(surface=screen, color=BLACK, center=(screen_x, screen_y), radius=radius, width=2)

def draw_info(screen, x, y, direction, linear_speed, angular_speed, mode, multiplier):
    """Отображает информацию о роботе на экране"""
    # TODO: Создайте список строк с информацией
    lines = [
        f"Позиция: ({int(x)}, {int(y)})",
        f"Направление: {int(direction % 360)}°",
        f"Линейная скорость: {int(linear_speed)} пикс/с",
        f"Угловая скорость: {int(angular_speed)} град/с",
        f"Режим: {mode}",
        f"Скорость: {int(multiplier * 100)}%",
        "Tab - режим, +/- скорость, R - сброс"
    ]

    # TODO: Отрисуйте каждую строку
    y_offset = 10
    for line in lines:
        text_surface = font.render(line, True, BLACK)
        screen.blit(source=text_surface, dest=(10, y_offset))
        y_offset += 25
        pass

# Игровой цикл
running = True
while running:
    # TODO: Обработка событий
    for event in pygame.event.get():
        if event.type == pygame.QUIT:
            running = False

        # Телепортация по клику мыши (работает в любом режиме)
        if event.type == pygame.MOUSEBUTTONDOWN:
            # Левая кнопка — телепорт в точку клика
            if event.button == 1:
                mouse_screen_x, mouse_screen_y = event.pos
                robot_x = mouse_screen_x - WIDTH // 2
                robot_y = HEIGHT // 2 - mouse_screen_y
                print(f"Телепортация в ({int(robot_x)}, {int(robot_y)})")
            # Средняя кнопка — возврат в центр
            if event.button == 2:
                robot_x = 0
                robot_y = 0
                robot_direction = 0
                print("Возврат в центр")

        if event.type == pygame.KEYDOWN:
            # Переключение режима
            if event.key == pygame.K_TAB:
                if control_mode == "keyboard":
                    control_mode = "mouse"
                    print("Режим: следование за мышью")
                else:
                    control_mode = "keyboard"
                    print("Режим: управление клавиатурой")
            # Сброс по R
            if event.key == pygame.K_r:
                robot_x = 0
                robot_y = 0
                robot_direction = 0
                print("Позиция сброшена")
            # TODO: Увеличение скорости по клавише =
            if event.key == pygame.K_EQUALS:
                speed_multiplier += 0.25
                # TODO: Ограничьте максимум (не больше 3.0)
                speed_multiplier = min(3.0, speed_multiplier)
                print(f"Скорость: {speed_multiplier * 100:.0f}%")
            # TODO: Уменьшение скорости по клавише -
            elif event.key == pygame.K_MINUS:
                speed_multiplier -= 0.25
                # TODO: Ограничьте минимум (не меньше 0.25)
                speed_multiplier = max(0.25, speed_multiplier)
                print(f"Скорость: {speed_multiplier * 100:.0f}%")

    # TODO: Вычисляйте delta time
    dt = clock.tick(60) / 1000.0

    # TODO: Обнуляем скорости (если клавиши не нажаты, робот стоит)
    linear_speed = 0
    angular_speed = 0

    # TODO: Проверяем текущий режим и выполняем соответствующий код
    if control_mode == "keyboard":
        # TODO: Код управления клавиатурой (WASD)
        keys = pygame.key.get_pressed()

        # Управление линейной скоростью
        if keys[pygame.K_w] and keys[pygame.K_s]:
            linear_speed = 0
        elif keys[pygame.K_w]:
            # TODO: Умножьте базовую скорость на множитель
            linear_speed = 150 * speed_multiplier
        elif keys[pygame.K_s]:
            linear_speed = -100 * speed_multiplier

        # Управление угловой скоростью
        if keys[pygame.K_a]:
            angular_speed = 120 * speed_multiplier
        if keys[pygame.K_d]:
            angular_speed = -120 * speed_multiplier

    elif control_mode == "mouse":
        # TODO: Код следования за мышью
        # Получаем позицию курсора
        mouse_screen_x, mouse_screen_y = pygame.mouse.get_pos()
        target_x = mouse_screen_x - WIDTH // 2
        target_y = HEIGHT // 2 - mouse_screen_y

        # Вычисляем расстояние и угол
        dx = target_x - robot_x
        dy = target_y - robot_y
        distance = math.hypot(dx, dy)

        # Вычисляем угол к цели
        angle_to_target_rad = math.atan2(dy, dx)
        angle_to_target_deg = math.degrees(angle_to_target_rad)

        # Вычисляем разницу углов
        angle_difference = angle_to_target_deg - robot_direction

        # Нормализуем разницу к диапазону -180 до 180
        if angle_difference > 180:
            angle_difference -= 360
        elif angle_difference < -180:
            angle_difference += 360

        # Устанавливаем угловую скорость для плавного поворота
        if abs(angle_difference) > 5:
            angular_speed = (angle_difference * 3) * speed_multiplier
        else:
            angular_speed = 0

        # Двигаемся к цели только если смотрим туда
        if distance > 5 and abs(angle_difference) < 30:
            linear_speed = 150 * speed_multiplier
        else:
            linear_speed = 0

    # TODO: Обновите направление робота
    robot_direction += angular_speed * dt

    # TODO: Обновите позицию робота
    # Сначала вычислите угол в радианах
    angle_rad = math.radians(robot_direction)

    # Затем вычислите изменение координат и обновите позицию
    robot_x += linear_speed * math.cos(angle_rad) * dt
    robot_y += linear_speed * math.sin(angle_rad) * dt

    # TODO: Ограничьте координаты робота границами
    if robot_x > MAX_X:
        robot_x = MAX_X
    elif robot_x < -MAX_X:
        robot_x = -MAX_X

    if robot_y > MAX_Y:
        robot_y = MAX_Y
    elif robot_y < -MAX_Y:
        robot_y = -MAX_Y

    # TODO: Залить экран белым
    screen.fill(WHITE)

    # TODO: Нарисовать робота
    draw_robot(screen=screen, x=robot_x, y=robot_y, direction=robot_direction, radius=20)

    # Обновление экрана
    pygame.display.flip()

pygame.quit()

# %%
import pygame
import math

pygame.init()

linear_speed = 0
angular_speed = 0

#linear_speed = 50
#angular_speed = 50

# TODO: Создайте окно 800x600
WIDTH = 800
HEIGHT = 600
screen = pygame.display.set_mode(size=(WIDTH, HEIGHT))

# TODO: Создайте часы для контроля FPS
clock = pygame.time.Clock()

# TODO: Определите цвета (WHITE, BLACK, BLUE)
WHITE = (255, 255, 255)
BLACK = (0, 0, 0)
BLUE = (0, 0, 255)

# TODO: Создайте шрифт размером 24
font = pygame.font.Font(None, 24)

dt = clock.tick(60) / 1000.0

# TODO: Переменные робота (математические координаты)
robot_x = 0  # начальная позиция в математических координатах
robot_y = 0  # начальная позиция в математических координатах
robot_direction = 0  # градусы, 0 = вправо

# Режим управления
control_mode = "keyboard"

# TODO: Создайте переменную для множителя скорости
speed_multiplier = 1.0  # Начальное значение 1.0

# TODO: Определите границы (математические координаты)
MAX_X = WIDTH // 2 - 20
MAX_Y = HEIGHT // 2 - 20

# TODO: Создайте пустой список для следа
trail = []
# TODO: Определите максимальную длину следа
MAX_TRAIL_LENGTH = 100  # Например, 100

def draw_robot(screen, x, y, direction, radius):
    """Рисует робота с направлением"""
    # TODO: Преобразуйте математические координаты в экранные

    screen_x = x + WIDTH // 2
    screen_y = HEIGHT // 2 - y
    draw_info(screen, x, y, direction, linear_speed, angular_speed, control_mode, speed_multiplier)
    # TODO: Нарисуйте круг (тело робота)
    pygame.draw.circle(screen, color=BLUE, center=(screen_x, screen_y), radius=radius)

    # TODO: Вычислите координаты треугольника для направления
    angle_rad = math.radians(direction)

    # Вершина треугольника (впереди)
    tip_x = screen_x + radius * math.cos(angle_rad)
    tip_y = screen_y - radius * math.sin(angle_rad)

    # Задние углы треугольника (левый и правый)
    left_x = screen_x + radius * math.cos(angle_rad + 2.5) * 0.5
    left_y = screen_y - radius * math.sin(angle_rad + 2.5) * 0.5

    right_x = screen_x + radius * math.cos(angle_rad - 2.5) * 0.5
    right_y = screen_y - radius * math.sin(angle_rad - 2.5) * 0.5

    # TODO: Нарисуйте треугольник
    pygame.draw.polygon(surface=screen, color=WHITE, points=[(tip_x, tip_y), (left_x, left_y), (right_x, right_y)])

    # TODO: Нарисуйте контур круга (толщина 2)
    pygame.draw.circle(surface=screen, color=BLACK, center=(screen_x, screen_y), radius=radius, width=2)

def draw_info(screen, x, y, direction, linear_speed, angular_speed, mode, multiplier):
    """Отображает информацию о роботе на экране"""
    # TODO: Создайте список строк с информацией
    lines = [
        f"Позиция: ({int(x)}, {int(y)})",
        f"Направление: {int(direction % 360)}°",
        f"Линейная скорость: {int(linear_speed)} пикс/с",
        f"Угловая скорость: {int(angular_speed)} град/с",
        f"Режим: {mode}",
        f"Скорость: {int(multiplier * 100)}%",
        "Tab - режим, +/- скорость, R - сброс"
    ]

    # TODO: Отрисуйте каждую строку
    y_offset = 10
    for line in lines:
        text_surface = font.render(line, True, BLACK)
        screen.blit(source=text_surface, dest=(10, y_offset))
        y_offset += 25
        pass

# TODO: Функция рисования следа
def draw_trail(screen, trail):
    """Рисует след за роботом"""
    # TODO: Проверьте, что в следе хотя бы 2 точки
    if len(trail) < 2:
        return  # Нечего рисовать

    # TODO: Нарисуйте линии между точками
    for i in range(len(trail) - 1):
        # Получаем две соседние точки
        point1 = trail[i]
        point2 = trail[i + 1]

        # TODO: Преобразуем математические координаты в экранные
        screen_x1 = point1[0] + WIDTH // 2
        screen_y1 = HEIGHT // 2 - point1[1]
        screen_x2 = point2[0] + WIDTH // 2
        screen_y2 = HEIGHT // 2 - point2[1]

        # TODO: Нарисуйте линию между точками
        pygame.draw.line(
            surface=screen,
            color=(150, 150, 255),  # Светло-синий
            start_pos=(screen_x1, screen_y1),
            end_pos=(screen_x2, screen_y2),
            width=2
        )

# Игровой цикл
running = True
while running:
    # TODO: Обработка событий
    for event in pygame.event.get():
        if event.type == pygame.QUIT:
            running = False

        # Телепортация по клику мыши (работает в любом режиме)
        if event.type == pygame.MOUSEBUTTONDOWN:
            # Левая кнопка — телепорт в точку клика
            if event.button == 1:
                mouse_screen_x, mouse_screen_y = event.pos
                robot_x = mouse_screen_x - WIDTH // 2
                robot_y = HEIGHT // 2 - mouse_screen_y
                print(f"Телепортация в ({int(robot_x)}, {int(robot_y)})")
            # Средняя кнопка — возврат в центр
            if event.button == 2:
                robot_x = 0
                robot_y = 0
                robot_direction = 0
                trail.clear()
                print("Возврат в центр")

        if event.type == pygame.KEYDOWN:
            # Переключение режима
            if event.key == pygame.K_TAB:
                if control_mode == "keyboard":
                    control_mode = "mouse"
                    print("Режим: следование за мышью")
                else:
                    control_mode = "keyboard"
                    print("Режим: управление клавиатурой")
            # Сброс по R
            if event.key == pygame.K_r:
                robot_x = 0
                robot_y = 0
                robot_direction = 0
                trail.clear()  # TODO: Очистите след
                print("Позиция и след сброшены")
            # TODO: Увеличение скорости по клавише =
            if event.key == pygame.K_EQUALS:
                speed_multiplier += 0.25
                # TODO: Ограничьте максимум (не больше 3.0)
                speed_multiplier = min(3.0, speed_multiplier)
                print(f"Скорость: {speed_multiplier * 100:.0f}%")
            # TODO: Уменьшение скорости по клавише -
            elif event.key == pygame.K_MINUS:
                speed_multiplier -= 0.25
                # TODO: Ограничьте минимум (не меньше 0.25)
                speed_multiplier = max(0.25, speed_multiplier)
                print(f"Скорость: {speed_multiplier * 100:.0f}%")

    # TODO: Вычисляйте delta time
    dt = clock.tick(60) / 1000.0

    # TODO: Обнуляем скорости (если клавиши не нажаты, робот стоит)
    linear_speed = 0
    angular_speed = 0

    # TODO: Проверяем текущий режим и выполняем соответствующий код
    if control_mode == "keyboard":
        # TODO: Код управления клавиатурой (WASD)
        keys = pygame.key.get_pressed()

        # Управление линейной скоростью
        if keys[pygame.K_w] and keys[pygame.K_s]:
            linear_speed = 0
        elif keys[pygame.K_w]:
            # TODO: Умножьте базовую скорость на множитель
            linear_speed = 150 * speed_multiplier
        elif keys[pygame.K_s]:
            linear_speed = -100 * speed_multiplier

        # Управление угловой скоростью
        if keys[pygame.K_a]:
            angular_speed = 120 * speed_multiplier
        if keys[pygame.K_d]:
            angular_speed = -120 * speed_multiplier

    elif control_mode == "mouse":
        # TODO: Код следования за мышью
        # Получаем позицию курсора
        mouse_screen_x, mouse_screen_y = pygame.mouse.get_pos()
        target_x = mouse_screen_x - WIDTH // 2
        target_y = HEIGHT // 2 - mouse_screen_y

        # Вычисляем расстояние и угол
        dx = target_x - robot_x
        dy = target_y - robot_y
        distance = math.hypot(dx, dy)

        # Вычисляем угол к цели
        angle_to_target_rad = math.atan2(dy, dx)
        angle_to_target_deg = math.degrees(angle_to_target_rad)

        # Вычисляем разницу углов
        angle_difference = angle_to_target_deg - robot_direction

        # Нормализуем разницу к диапазону -180 до 180
        if angle_difference > 180:
            angle_difference -= 360
        elif angle_difference < -180:
            angle_difference += 360

        # Устанавливаем угловую скорость для плавного поворота
        if abs(angle_difference) > 5:
            angular_speed = (angle_difference * 3) * speed_multiplier
        else:
            angular_speed = 0

        # Двигаемся к цели только если смотрим туда
        if distance > 5 and abs(angle_difference) < 30:
            linear_speed = 150 * speed_multiplier
        else:
            linear_speed = 0

    # TODO: Обновите направление робота
    robot_direction += angular_speed * dt

    # TODO: Обновите позицию робота
    # Сначала вычислите угол в радианах
    angle_rad = math.radians(robot_direction)

    # Затем вычислите изменение координат и обновите позицию
    robot_x += linear_speed * math.cos(angle_rad) * dt
    robot_y += linear_speed * math.sin(angle_rad) * dt

    # TODO: Добавьте текущую позицию в след
    trail.append((robot_x, robot_y))
    # TODO: Ограничьте длину следа
    if len(trail) > MAX_TRAIL_LENGTH:
        trail.pop(0)  # Удаляем первый (самый старый) элемент

    # TODO: Ограничьте координаты робота границами
    if robot_x > MAX_X:
        robot_x = MAX_X
    elif robot_x < -MAX_X:
        robot_x = -MAX_X

    if robot_y > MAX_Y:
        robot_y = MAX_Y
    elif robot_y < -MAX_Y:
        robot_y = -MAX_Y

    # TODO: Залить экран белым
    screen.fill(WHITE)

    # TODO: Нарисуйте след
    draw_trail(screen, trail)

    # TODO: Нарисовать робота
    draw_robot(screen=screen, x=robot_x, y=robot_y, direction=robot_direction, radius=20)

    # Обновление экрана
    pygame.display.flip()

pygame.quit()

# %%
import pygame
import math
import random

pygame.init()

linear_speed = 0
angular_speed = 0

#linear_speed = 50
#angular_speed = 50

# TODO: Создайте окно 800x600
WIDTH = 800
HEIGHT = 600
screen = pygame.display.set_mode(size=(WIDTH, HEIGHT))

# TODO: Создайте часы для контроля FPS
clock = pygame.time.Clock()

# TODO: Определите цвета (WHITE, BLACK, BLUE)
WHITE = (255, 255, 255)
BLACK = (0, 0, 0)
BLUE = (0, 0, 255)

# TODO: Создайте шрифт размером 24
font = pygame.font.Font(None, 24)

dt = clock.tick(60) / 1000.0

# TODO: Переменные робота (математические координаты)
robot_x = 0  # начальная позиция в математических координатах
robot_y = 0  # начальная позиция в математических координатах
robot_direction = 0  # градусы, 0 = вправо

# Режим управления
control_mode = "keyboard"

# TODO: Создайте переменную для множителя скорости
speed_multiplier = 1.0  # Начальное значение 1.0

# TODO: Определите границы (математические координаты)
MAX_X = WIDTH // 2 - 20
MAX_Y = HEIGHT // 2 - 20

# TODO: Создайте пустой список для следа
trail = []
# TODO: Определите максимальную длину следа
MAX_TRAIL_LENGTH = 100  # Например, 100

# TODO: Создайте список для хранения точек
coins = []
# TODO: Создайте переменную для счёта
score = 0
# TODO: Определите цвета точек
COIN_COLORS = [
    (255, 200, 0),   # Золотой
    (0, 200, 255),   # Голубой
    (255, 100, 200), # Розовый
    (150, 255, 100)  # Зелёный
]
# TODO: Определите радиус точки и радиус робота
COIN_RADIUS = 8
ROBOT_RADIUS = 20  # Совпадает с радиусом отрисовки робота

# TODO: Запомните время старта игры
game_start_time = pygame.time.get_ticks()
# TODO: Длительность игры в секундах
GAME_DURATION = 60

def spawn_coin():
    """Создаёт новую точку в случайном месте"""
    # TODO: Случайные координаты в пределах границ
    x = random.randint(-MAX_X, MAX_X)
    y = random.randint(-MAX_Y, MAX_Y)
    # TODO: Случайный цвет
    color = random.choice(COIN_COLORS)
    # TODO: Создайте словарь с данными точки
    coin = {
        'x': x,
        'y': y,
        'color': color,
        'radius': COIN_RADIUS
    }
    return coin

# TODO: Создайте несколько начальных точек
for i in range(5):
    coins.append(spawn_coin())

def draw_robot(screen, x, y, direction, radius):
    """Рисует робота с направлением"""
    # TODO: Преобразуйте математические координаты в экранные

    screen_x = x + WIDTH // 2
    screen_y = HEIGHT // 2 - y
    draw_info(screen, x, y, direction, linear_speed, angular_speed, control_mode, speed_multiplier, score, max(0, GAME_DURATION - (pygame.time.get_ticks() - game_start_time) / 1000))
    # TODO: Нарисуйте круг (тело робота)
    pygame.draw.circle(screen, color=BLUE, center=(screen_x, screen_y), radius=radius)

    # TODO: Вычислите координаты треугольника для направления
    angle_rad = math.radians(direction)

    # Вершина треугольника (впереди)
    tip_x = screen_x + radius * math.cos(angle_rad)
    tip_y = screen_y - radius * math.sin(angle_rad)

    # Задние углы треугольника (левый и правый)
    left_x = screen_x + radius * math.cos(angle_rad + 2.5) * 0.5
    left_y = screen_y - radius * math.sin(angle_rad + 2.5) * 0.5

    right_x = screen_x + radius * math.cos(angle_rad - 2.5) * 0.5
    right_y = screen_y - radius * math.sin(angle_rad - 2.5) * 0.5

    # TODO: Нарисуйте треугольник
    pygame.draw.polygon(surface=screen, color=WHITE, points=[(tip_x, tip_y), (left_x, left_y), (right_x, right_y)])

    # TODO: Нарисуйте контур круга (толщина 2)
    pygame.draw.circle(surface=screen, color=BLACK, center=(screen_x, screen_y), radius=radius, width=2)

def draw_info(screen, x, y, direction, linear_speed, angular_speed, mode, multiplier, score, time_left):
    """Отображает информацию о роботе на экране"""
    # TODO: Создайте список строк с информацией
    lines = [
        f"Счёт: {score}",
        f"Время: {int(time_left)}с",
        f"Позиция: ({int(x)}, {int(y)})",
        f"Направление: {int(direction % 360)}°",
        f"Линейная скорость: {int(linear_speed)} пикс/с",
        f"Угловая скорость: {int(angular_speed)} град/с",
        f"Режим: {mode}",
        f"Скорость: {int(multiplier * 100)}%",
        "Tab - режим, +/- скорость, R - перезапуск"
    ]

    # TODO: Отрисуйте каждую строку
    y_offset = 10
    for line in lines:
        text_surface = font.render(line, True, BLACK)
        screen.blit(source=text_surface, dest=(10, y_offset))
        y_offset += 25
        pass

def draw_trail(screen, trail):
    """Рисует след за роботом"""
    # TODO: Проверьте, что в следе хотя бы 2 точки
    if len(trail) < 2:
        return  # Нечего рисовать

    # TODO: Нарисуйте линии между точками
    for i in range(len(trail) - 1):
        # Получаем две соседние точки
        point1 = trail[i]
        point2 = trail[i + 1]

        # TODO: Преобразуем математические координаты в экранные
        screen_x1 = point1[0] + WIDTH // 2
        screen_y1 = HEIGHT // 2 - point1[1]
        screen_x2 = point2[0] + WIDTH // 2
        screen_y2 = HEIGHT // 2 - point2[1]

        # TODO: Нарисуйте линию между точками
        pygame.draw.line(
            surface=screen,
            color=(150, 150, 255),  # Светло-синий
            start_pos=(screen_x1, screen_y1),
            end_pos=(screen_x2, screen_y2),
            width=2
        )

def draw_coins(screen, coins):
    """Рисует все точки на экране"""
    for coin in coins:
        # TODO: Преобразуйте математические координаты в экранные
        screen_x = coin['x'] + WIDTH // 2
        screen_y = HEIGHT // 2 - coin['y']
        # TODO: Нарисуйте точку
        pygame.draw.circle(
            surface=screen,
            color=coin['color'],
            center=(screen_x, screen_y),
            radius=coin['radius']
        )

def restart_game():
    """Перезапускает игру"""
    global score, coins, game_start_time, robot_x, robot_y, robot_direction, trail
    # TODO: Сбросьте счёт
    score = 0
    # TODO: Очистите список точек
    coins.clear()
    # TODO: Создайте новые точки
    for i in range(5):
        coins.append(spawn_coin())
    # TODO: Сбросьте позицию робота
    robot_x = 0
    robot_y = 0
    robot_direction = 0
    # TODO: Очистите след
    trail.clear()
    # TODO: Перезапустите таймер
    game_start_time = pygame.time.get_ticks()
    print("Игра перезапущена!")

# Игровой цикл
running = True
while running:
    # TODO: Вычислите прошедшее/оставшееся время
    elapsed_time = (pygame.time.get_ticks() - game_start_time) / 1000
    remaining_time = GAME_DURATION - elapsed_time
    if remaining_time <= 0:
        remaining_time = 0

    # TODO: Обработка событий
    for event in pygame.event.get():
        if event.type == pygame.QUIT:
            running = False

        # Телепортация по клику мыши (работает в любом режиме)
        if event.type == pygame.MOUSEBUTTONDOWN:
            # Левая кнопка — телепорт в точку клика
            if event.button == 1:
                mouse_screen_x, mouse_screen_y = event.pos
                robot_x = mouse_screen_x - WIDTH // 2
                robot_y = HEIGHT // 2 - mouse_screen_y
                print(f"Телепортация в ({int(robot_x)}, {int(robot_y)})")
            # Средняя кнопка — возврат в центр
            if event.button == 2:
                robot_x = 0
                robot_y = 0
                robot_direction = 0
                trail.clear()
                print("Возврат в центр")

        if event.type == pygame.KEYDOWN:
            # Переключение режима
            if event.key == pygame.K_TAB:
                if control_mode == "keyboard":
                    control_mode = "mouse"
                    print("Режим: следование за мышью")
                else:
                    control_mode = "keyboard"
                    print("Режим: управление клавиатурой")
            # Перезапуск по R
            if event.key == pygame.K_r:
                restart_game()
            # TODO: Увеличение скорости по клавише =
            if event.key == pygame.K_EQUALS:
                speed_multiplier += 0.25
                # TODO: Ограничьте максимум (не больше 3.0)
                speed_multiplier = min(3.0, speed_multiplier)
                print(f"Скорость: {speed_multiplier * 100:.0f}%")
            # TODO: Уменьшение скорости по клавише -
            elif event.key == pygame.K_MINUS:
                speed_multiplier -= 0.25
                # TODO: Ограничьте минимум (не меньше 0.25)
                speed_multiplier = max(0.25, speed_multiplier)
                print(f"Скорость: {speed_multiplier * 100:.0f}%")

    # TODO: Вычисляйте delta time
    dt = clock.tick(60) / 1000.0

    # TODO: Обнуляем скорости (если клавиши не нажаты, робот стоит)
    linear_speed = 0
    angular_speed = 0

    # Блокируем управление, если время вышло
    if remaining_time > 0:
        # TODO: Проверяем текущий режим и выполняем соответствующий код
        if control_mode == "keyboard":
            # TODO: Код управления клавиатурой (WASD)
            keys = pygame.key.get_pressed()

            # Управление линейной скоростью
            if keys[pygame.K_w] and keys[pygame.K_s]:
                linear_speed = 0
            elif keys[pygame.K_w]:
                # TODO: Умножьте базовую скорость на множитель
                linear_speed = 150 * speed_multiplier
            elif keys[pygame.K_s]:
                linear_speed = -100 * speed_multiplier

            # Управление угловой скоростью
            if keys[pygame.K_a]:
                angular_speed = 120 * speed_multiplier
            if keys[pygame.K_d]:
                angular_speed = -120 * speed_multiplier

        elif control_mode == "mouse":
            # TODO: Код следования за мышью
            # Получаем позицию курсора
            mouse_screen_x, mouse_screen_y = pygame.mouse.get_pos()
            target_x = mouse_screen_x - WIDTH // 2
            target_y = HEIGHT // 2 - mouse_screen_y

            # Вычисляем расстояние и угол
            dx = target_x - robot_x
            dy = target_y - robot_y
            distance = math.hypot(dx, dy)

            # Вычисляем угол к цели
            angle_to_target_rad = math.atan2(dy, dx)
            angle_to_target_deg = math.degrees(angle_to_target_rad)

            # Вычисляем разницу углов
            angle_difference = angle_to_target_deg - robot_direction

            # Нормализуем разницу к диапазону -180 до 180
            if angle_difference > 180:
                angle_difference -= 360
            elif angle_difference < -180:
                angle_difference += 360

            # Устанавливаем угловую скорость для плавного поворота
            if abs(angle_difference) > 5:
                angular_speed = (angle_difference * 3) * speed_multiplier
            else:
                angular_speed = 0

            # Двигаемся к цели только если смотрим туда
            if distance > 5 and abs(angle_difference) < 30:
                linear_speed = 150 * speed_multiplier
            else:
                linear_speed = 0

    # TODO: Обновите направление робота
    robot_direction += angular_speed * dt

    # TODO: Обновите позицию робота
    # Сначала вычислите угол в радианах
    angle_rad = math.radians(robot_direction)

    # Затем вычислите изменение координат и обновите позицию
    robot_x += linear_speed * math.cos(angle_rad) * dt
    robot_y += linear_speed * math.sin(angle_rad) * dt

    # TODO: Добавьте текущую позицию в след
    trail.append((robot_x, robot_y))
    # TODO: Ограничьте длину следа
    if len(trail) > MAX_TRAIL_LENGTH:
        trail.pop(0)  # Удаляем первый (самый старый) элемент

    # TODO: Ограничьте координаты робота границами
    if robot_x > MAX_X:
        robot_x = MAX_X
    elif robot_x < -MAX_X:
        robot_x = -MAX_X

    if robot_y > MAX_Y:
        robot_y = MAX_Y
    elif robot_y < -MAX_Y:
        robot_y = -MAX_Y

    # TODO: Проверяем столкновения с точками
    coins_to_remove = []
    for coin in coins:
        dx = coin['x'] - robot_x
        dy = coin['y'] - robot_y
        distance = math.hypot(dx, dy)
        if distance < ROBOT_RADIUS + coin['radius']:
            coins_to_remove.append(coin)
            score += 1
    # TODO: Удалите собранные точки
    for coin in coins_to_remove:
        coins.remove(coin)
    # TODO: Если точек мало - добавьте новую
    if len(coins) < 5:
        coins.append(spawn_coin())

    # TODO: Залить экран белым
    screen.fill(WHITE)

    # TODO: Нарисуйте след
    draw_trail(screen, trail)

    # TODO: Нарисовать робота
    draw_robot(screen=screen, x=robot_x, y=robot_y, direction=robot_direction, radius=ROBOT_RADIUS)

    # TODO: Нарисуйте точки
    draw_coins(screen, coins)

    # Обновление экрана
    pygame.display.flip()

pygame.quit()
